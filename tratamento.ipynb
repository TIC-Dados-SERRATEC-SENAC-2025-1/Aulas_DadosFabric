# %%
import pandas as pd

# %%
df=pd.read_csv("Agregados_por_setores_basico_BR_20250417.csv", encoding='latin1', sep=';')
# Out:
# C:\Users\isabel.barboza\AppData\Local\Temp\ipykernel_24280\3835331946.py:1: DtypeWarning: Columns (2,3,9,11,13,14,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Agregados_por_setores_basico_BR_20250417.csv", encoding='latin1', sep=';')

# %%
df.head(50)
# Out:
#        CD_SETOR SITUACAO CD_SIT CD_TIPO     AREA_KM2  CD_REGIAO NM_REGIAO  \
# 0   1,10002E+14   Urbana      1       0    0,5393102          1     Norte
# 1   1,10002E+14   Urbana      1       0    0,2362175          1     Norte
# 2   1,10002E+14   Urbana      1       0    0,2118666          1     Norte
# 3   1,10002E+14   Urbana      1       0    0,5054477          1     Norte
# 4   1,10002E+14   Urbana      1       0    0,2990424          1     Norte
# 5   1,10002E+14   Urbana      1       0    0,1850833          1     Norte
# 6   1,10002E+14   Urbana      1       0    0,2935376          1     Norte
# 7   1,10002E+14   Urbana      1       0    0,5708013          1     Norte
# 8   1,10002E+14   Urbana      2       0    0,3811151          1     Norte
# 9   1,10002E+14   Urbana      1       0    0,1838927          1     Norte
# 10  1,10002E+14   Urbana      1       0    0,2208879          1     Norte
# 11  1,10002E+14   Urbana      1       0    0,2234621          1     Norte
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468099 entries, 0 to 468098
# Data columns (total 36 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   CD_SETOR    468099 non-null  object
#  1   SITUACAO    466996 non-null  object
#  2   CD_SIT      468099 non-null  object
#  3   CD_TIPO     468099 non-null  object
#  4   AREA_KM2    468099 non-null  object
#  5   CD_REGIAO   468099 non-null  int64
#  6   NM_REGIAO   468099 non-null  object
#  7   CD_UF       468099 non-null  int64
#  8   NM_UF       468099 non-null  object
#  9   CD_MUN      468099 non-null  object
#  10  NM_MUN      468097 non-null  object
#  11  CD_DIST     468099 non-null  object
#  12  NM_DIST     468097 non-null  object
#  13  CD_SUBDIST  468099 non-null  object
#  14  NM_SUBDIST  70874 non-null   object
#  15  CD_BAIRRO   468099 non-null  object
#  16  NM_BAIRRO   168050 non-null  object
#  17  CD_NU       468099 non-null  object
# ...

# %%
print(df['NM_MUN'].dropna().unique())
# Out:
# ["Alta Floresta D'Oeste" 'Ariquemes' 'Cabixi' ... 'Vila Boa'
#  'Vila Propício' 'Brasília']

# %%
colunas = [
    "CD_SETOR", "SITUACAO", "AREA_KM2",
    "CD_REGIAO", "NM_REGIAO",
    "CD_UF", "NM_UF",
    "CD_MUN", "NM_MUN",
    "CD_DIST", "NM_DIST",
    "CD_SUBDIST", "NM_SUBDIST",
    "CD_BAIRRO", "NM_BAIRRO",
    "CD_NU", "NM_NU",
    "v0001", "v0002", "v0003", "v0004", "v0005", "v0006", "v0007"
]

df = df[colunas]
df_petropolis = df[df["NM_MUN"] == "Petrópolis"]

# %%
df_petropolis.head(10)
# Out:
#            CD_SETOR SITUACAO   AREA_KM2  CD_REGIAO NM_REGIAO  CD_UF  \
# 241017  3,30391E+14   Urbana  0,0134471          3   Sudeste     33
# 241018  3,30391E+14   Urbana  0,0168073          3   Sudeste     33
# 241019  3,30391E+14   Urbana  0,0205322          3   Sudeste     33
# 241020  3,30391E+14   Urbana  0,0270654          3   Sudeste     33
# 241021  3,30391E+14   Urbana  0,0118641          3   Sudeste     33
# 241022  3,30391E+14   Urbana  0,0311398          3   Sudeste     33
# 241023  3,30391E+14   Urbana  0,0228381          3   Sudeste     33
# 241024  3,30391E+14   Urbana  0,0145805          3   Sudeste     33
# 241025  3,30391E+14   Urbana  0,1452985          3   Sudeste     33
# 241026  3,30391E+14   Urbana  0,1874605          3   Sudeste     33
#
#                  NM_UF   CD_MUN      NM_MUN    CD_DIST  ... NM_BAIRRO CD_NU  \
# 241017  Rio de Janeiro  3303906  Petrópolis  330390605  ...       NaN     .
# ...

# %%
df_petropolis.to_csv("petropolis_censo2022.csv", index=False)
